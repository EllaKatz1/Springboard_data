# %%
import pandas as pd
import numpy as np

# %%
#Data loading:
Phenotypes = pd.read_csv(r"C:\Users\Ella Katz\Desktop\Post-doc\Personal\Springboard\git_hub_projects\Second_capstone\Datasets\All_Data_emmeans_info_V1.csv")
Classifications = pd.read_csv(r"C:\Users\Ella Katz\Desktop\Post-doc\Personal\Springboard\git_hub_projects\Second_capstone\Datasets\Seeds_classification.csv")
Environmental_data = pd.read_csv(r"C:\Users\Ella Katz\Desktop\Post-doc\Personal\Springboard\git_hub_projects\Second_capstone\Datasets\Environmental_data.csv")

# %%
print(Phenotypes.shape)
print(Classifications.shape)
print(Environmental_data.shape)
# Out:
# (3888, 48)
# (797, 2)
# (1131, 212)

# %%
print(Phenotypes.head())
print(Classifications.head())
print(Environmental_data.head())
# Out:
#   CS_number         name country  latitude  longitude     collector seq_by  \
# 0   CS76347      Aitba-2     MAR   31.4800      0.000             0    MPI
# 1   CS76347      Aitba-2     MAR   31.4800      0.000             0    MPI
# 2   CS76347      Aitba-2     MAR   31.4800      0.000             0    MPI
# 3   CS76347      Aitba-2     MAR   31.4800      0.000             0    MPI
# 4   CS76350  Vezzano-2.2     ITA   46.6297     10.817  Joerg Wunder    MPI
#
#   Experiment N_source  N_concentration  ... Aliphatic   Indolic        C3  \
# 0          C  NH4HCO3              0.1  ...  1.175086  0.166070  0.776150
# 1          C  NH4HCO3              1.0  ...  3.728467  0.424037  3.111164
# 2          C     KNO3              0.1  ...  0.348629  0.072737  0.210332
# 3          C     KNO3              1.0  ...  0.397285  0.044411  0.244144
# 4          C     KNO3              1.0  ...  0.477350  0.043457  0.269797
#
#          C4  C3_ratio           Alk          GSOH        SC        LC  \
# 0  0.000000  1.000000  4.629625e-01           NaN  0.776150  0.398936
# 1  0.202374  0.957367  8.277334e-01  0.000000e+00  3.313538  0.414929
# 2  0.000000  1.000000  4.850000e-13           NaN  0.210332  0.138297
# 3  0.011127  0.973222  9.444688e-01           NaN  0.255271  0.142014
# 4  0.120865  0.690614  7.421784e-01  6.210000e-15  0.390662  0.086688
#
#    Total_GSL
# 0   1.341156
# 1   4.152504
# 2   0.421366
# 3   0.441696
# 4   0.520807
#
# [5 rows x 48 columns]
#   CS_number Seeds_classification
# 0   CS76350                Allyl
# 1   CS76351                Allyl
# 2   CS76352                 3OHP
# 3   CS76353                Allyl
# 4   CS76354                Allyl
#         lng      lat   id    name country CS_number          group  \
# 0  0.683333  47.4000   88     CYR     FRA   CS76790  WesternEurope
# 1 -4.066670  48.5167  108  LDV-18     FRA   CS77013  WesternEurope
# 2 -4.066670  48.5167  139  LDV-46     FRA   CS77014  WesternEurope
# 3  3.933330  47.3500  159  MAR2-3     FRA   CS77070  WesternEurope
# 4 -1.166670  44.6500  265   PYL-6     FRA   CS77198        Admixed
#
#     CO_Spring  CO_Summer  NO2_Spring  ...  Distance_to_the_coast  \
# 0  130.258718  96.078134  302.165353  ...                  166.5
# 1  129.886521  96.078134  201.771654  ...                   17.0
# 2  129.886521  96.078134  201.771654  ...                   17.0
# 3  129.921259  92.598426  229.002624  ...                  341.0
# 4  128.549657  94.881889  186.679788  ...                    2.5
#
#                                    Bailey_ecoregions  \
# 0  Permanently humid western oceanic broadleaf fo...
# 1  Permanently humid western oceanic broadleaf fo...
# 2  Permanently humid western oceanic broadleaf fo...
# 3                              Forest-alpine meadows
# 4  Permanently humid western oceanic broadleaf fo...
#
#                             Land_cover_2000  UMD_Land_cover_classification  \
# 0  Artificial surfaces and associated areas                      Croplands
# 1          Cropland / Shrub or Grass Cover                       Croplands
# 2          Cropland / Shrub or Grass Cover                       Croplands
# 3             Herbaceous Cover, closed-open                  Mixed_Forests
# 4  Artificial surfaces and associated areas    Evergreen_Needleleaf_Forest
#
#       Distribution_of_Cultivation_Intensity  \
# 0  Cold deciduous forest without evergreens
# 1                                       NaN
# 2                                       NaN
# 3  Cold deciduous forest without evergreens
# 4                                       NaN
#
#                               Koppen_Geiger         Geological_ages  \
# 0  Temperate/Without dry season/Warm summer              Quaternary
# 1  Temperate/Without dry season/Warm summer                Devonian
# 2  Temperate/Without dry season/Warm summer                Devonian
# 3  Temperate/Without dry season/Warm summer  Paleozoic, Precambrian
# 4                                       NaN              Quaternary
#
#    Soil_types  SoilGrids_TAXNWRB  SoilGrids_TAXOUSDA
# 0        51.0   Haplic Cambisols              Udalfs
# 1         NaN   Haplic Cambisols             Aquepts
# 2         NaN   Haplic Cambisols             Aquepts
# 3         6.0   Haplic Cambisols            Ochrepts
# 4         NaN   Haplic Cambisols              Udults
#
# [5 rows x 212 columns]

# %%
for col in Phenotypes.columns:
    print(col)
# Out:
# CS_number
# name
# country
# latitude
# longitude
# collector
# seq_by
# Experiment
# N_source
# N_concentration
# N_treatment
# Leaf_Area
# Total_roots
# PR_length
# Number_of_LR
# Total_LR
# LR_density
# LR_length
# LR_to_total_roots
# LR_to_PR
# X2MSO
# X3OHP
# X4OHB
# X3MSO
# OH_3_Butenyl
# X4MSO
# Allyl
# X5MSO
# Branches
# X3_Butenyl
# X6MSO
# X3MT
# X7MSO
# X4_Pentenyl
# X4MT
# X8MSO
# I3M
# X4MOI3M
# Aliphatic
# Indolic
# C3
# C4
# C3_ratio
# Alk
# GSOH
# SC
# LC
# Total_GSL

# %%
#Data joining:
Data = pd.merge(Phenotypes, Classifications, how="left", on="CS_number")
Data_1 = pd.merge(Data, Environmental_data, how="left", on="CS_number")

print(Phenotypes.shape)
print(Environmental_data.shape)
print(Data_1.shape)
# Out:
# (3888, 48)
# (1131, 212)
# (3888, 260)

# %%
for col in Data_1.columns:
    print(col)
# Out:
# CS_number
# name_x
# country_x
# latitude
# longitude
# collector
# seq_by
# Experiment
# N_source
# N_concentration
# N_treatment
# Leaf_Area
# Total_roots
# PR_length
# Number_of_LR
# Total_LR
# LR_density
# LR_length
# LR_to_total_roots
# LR_to_PR
# X2MSO
# X3OHP
# X4OHB
# X3MSO
# OH_3_Butenyl
# X4MSO
# Allyl
# X5MSO
# Branches
# X3_Butenyl
# X6MSO
# X3MT
# X7MSO
# X4_Pentenyl
# X4MT
# X8MSO
# I3M
# X4MOI3M
# Aliphatic
# Indolic
# C3
# C4
# C3_ratio
# Alk
# GSOH
# SC
# LC
# Total_GSL
# Seeds_classification
# lng
# lat
# id
# name_y
# country_y
# group
# CO_Spring
# CO_Summer
# NO2_Spring
# NO2_Summer
# O3_Spring
# O3_Summer
# SIB3_carbon_flux_spring
# SIB3_carbon_flux_summer
# UV_index_spring
# UV_index_summer
# Solar_insolation_spring
# Solar_insolation_summer
# Net_radiation_spring
# Net_radiation_summer
# WATER_EQUIVALENT_ANOMALY_spring
# WATER_EQUIVALENT_ANOMALY_summer
# Rainfall_spring
# Rainfall_summer
# Precipitable_water_spring
# Precipitable_water_summer
# LTemp_day_spring
# LTemp_day_summer
# Ltemp__night_spring
# Ltemp__night_summer
# NDVI_Spring
# NDVI_Summer
# LAI_Spring
# LAI_Summer
# PET
# ET
# LE
# Aridity_index
# Climatic_water_deficit
# Number_of_dry_months
# GPP_Spring
# GPP_Summer
# NPP_Spring
# NPP_Summer
# Topography
# SRTM_elevation
# SMT_Spring
# SMT_Summer
# SMN_Spring
# SMN_Summer
# TCI_Spring
# TCI_Summer
# VCI_Spring
# VCI_Summer
# VHI_Spring
# VHI_Summer
# CO2_Emissions
# WB_PVOUT
# WB_GHI
# WB_DIF
# WB_GTI
# WB_OPTA
# WB_DNI
# WB_TEMP
# WC_ELE
# GPCC_Spring
# GPCC_Summer
# WC2_Tmin_spring
# WC2_Tmin_summer
# WC2_Tmax_spring
# WC2_Tmax_summer
# WC2_Pre_spring
# WC2_Pre_summer
# WC2_Solar_radiation_spring
# WC2_Solar_radiation_summer
# WC2_Average_temperature_spring
# WC2_Average_temperature_summer
# WC2_Water_vapor_pressure_spring
# WC2_Water_vapor_pressure_summer
# WC2_BIO1
# WC2_BIO2
# WC2_BIO3
# WC2_BIO4
# WC2_BIO5
# WC2_BIO6
# WC2_BIO7
# WC2_BIO8
# WC2_BIO9
# WC2_BIO10
# WC2_BIO11
# WC2_BIO12
# WC2_BIO13
# WC2_BIO14
# WC2_BIO15
# WC2_BIO16
# WC2_BIO17
# WC2_BIO18
# WC2_BIO19
# CHELSA_Tmin_Spring
# CHELSA_Tmin_Summer
# CHELSA_Tmax_spring
# CHELSA_Tmax_summer
# CHELSA_Tmean_spring
# CHELSA_Tmean_summer
# CHELSA_Interann_Temp
# CHELSA_Pre_spring
# CHELSA_Pre_summer
# CHELSA_Interann_pre
# CHELSA_BIO1
# CHELSA_BIO2
# CHELSA_BIO3
# CHELSA_BIO4
# CHELSA_BIO5
# CHELSA_BIO6
# CHELSA_BIO7
# CHELSA_BIO8
# CHELSA_BIO9
# CHELSA_BIO10
# CHELSA_BIO11
# CHELSA_BIO12
# CHELSA_BIO13
# CHELSA_BIO14
# CHELSA_BIO15
# CHELSA_BIO16
# CHELSA_BIO17
# CHELSA_BIO18
# CHELSA_BIO19
# CRU_Cld_spring
# CRU_Cld_summer
# CRU_Dtr_spring
# CRU_Dtr_summer
# CRU_Frs_spring
# CRU_Frs_summer
# CRU_Pre_spring
# CRU_Pre_summer
# CRU_Tmp_spring
# CRU_Tmp_summer
# CRU_Tmn_spring
# CRU_Tmn_summer
# CRU_Tmx_spring
# CRU_Tmx_summer
# CRU_Vap_spring
# CRUVap_summer
# CRU_Wet_spring
# CRU_Wet_summer
# CRU_PET_Spring
# CRU_PET_Summer
# Bedrock_topography
# dNPPdP
# dNPPdT
# CRU_NPP
# NPP_based_on_GPCP
# NPP_based_on_GPCP_VASClimO
# GPCC_VASClimO_Precipitation
# CRU_Precipitation
# CRU_Temperature
# Griesser_Precip_GPCC
# GPCC_Fulldata_Precipitation
# Aridity_index_of_De_Martonne_GPCC_Fulldata
# Aridity_index_of_De_Martonne_GPCC_VASClimO
# Aridity_index_of_De_Martonne_CRU
# HWSD_Topsoil_ref_bulk_dens
# HWSD_Topsoil_clay_fraction
# HWSD_Topsoil_gravel_content
# HWSD_Topsoil_silt_fraction
# HWSD_Topsoil_sand_fraction
# HWSD_Topsoil_organic_carbon
# HWSD_Topsoil_pH
# HWSD_Subsoil_ref_bulk_dens
# HWSD_Subsoil_clay_fraction
# HWSD_Subsoil_gravel_content
# HWSD_Subsoil_silt_fraction
# HWSD_Subsoil_sand_fraction
# HWSD_Subsoil_organic_carbon
# HWSD_Subsoil_pH
# HWSD_Spatially_dominan_major_soil_group_FAO
# ISRIC_WISE_SoilCarbonate_Carbon_Dens
# ISRIC_WISE_Soil_Org_Carbon_Dens
# ISRIC_WISE_Soil_pH
# ISRIC_WISE_Total_AvailWater_cap
# SoilGrids_BDRICM
# SoilGrids_BLDFIE
# SoilGrids_CECSOL
# SoilGrids_CLYPPT
# SoilGrids_CRFVOL
# SoilGrids_OCSTHA
# SoilGrids_ORCDRC
# SoilGrids_PHIHOX
# SoilGrids_PHIKCL
# SoilGrids_SLTPPT
# SoilGrids_SNDPPT
# GAEZ_Nutrient_availability
# GAEZ_Nutrient_retention_capacity
# GAEZ_Rooting_conditions
# GAEZ_Oxygen_availability_to_roots
# GAEZ_Excess_salts
# GAEZ_Toxicity
# Plant_Extractable_Water_Capacity_of_Soil
# IGBP_DIS_Soil_pH
# Suitability_for_Agriculture
# Growing_degree_days
# Distance_to_the_coast
# Bailey_ecoregions
# Land_cover_2000
# UMD_Land_cover_classification
# Distribution_of_Cultivation_Intensity
# Koppen_Geiger
# Geological_ages
# Soil_types
# SoilGrids_TAXNWRB
# SoilGrids_TAXOUSDA

# %%
#Data Organization:
#Deleting duplicated and unnecessary columns:
Data_2 = Data_1
Data_2 = Data_2.drop(["name_x", "country_x", "collector", "seq_by", "lng", "lat", "name_y", "country_y"], axis=1)

# %%
Data_2.head()
# Out:
#   CS_number  latitude  longitude Experiment N_source  N_concentration  \
# 0   CS76347   31.4800      0.000          C  NH4HCO3              0.1
# 1   CS76347   31.4800      0.000          C  NH4HCO3              1.0
# 2   CS76347   31.4800      0.000          C     KNO3              0.1
# 3   CS76347   31.4800      0.000          C     KNO3              1.0
# 4   CS76350   46.6297     10.817          C     KNO3              1.0
#
#    N_treatment  Leaf_Area  Total_roots  PR_length  ...  Distance_to_the_coast  \
# 0  NH4HCO3_0.1   5.314220    52.580000  42.595000  ...                  196.0
# 1    NH4HCO3_1   8.452896    81.236667  48.290000  ...                  196.0
# 2     KNO3_0.1   5.503015    31.255000  31.255000  ...                  196.0
# 3       KNO3_1   7.056943    57.660000  46.756667  ...                  196.0
# 4       KNO3_1   3.741400    31.390000  31.390000  ...                  199.0
#
#                               Bailey_ecoregions  \
# 0  Shrub-forest-meadow of Mediterranean climate
# 1  Shrub-forest-meadow of Mediterranean climate
# 2  Shrub-forest-meadow of Mediterranean climate
# 3  Shrub-forest-meadow of Mediterranean climate
# 4                         Forest-alpine meadows
#
#                                Land_cover_2000  UMD_Land_cover_classification  \
# 0  Tree Cover, broadleaved, deciduous, closed         Wooded_Grassland/Shrubs
# 1  Tree Cover, broadleaved, deciduous, closed         Wooded_Grassland/Shrubs
# 2  Tree Cover, broadleaved, deciduous, closed         Wooded_Grassland/Shrubs
# 3  Tree Cover, broadleaved, deciduous, closed         Wooded_Grassland/Shrubs
# 4  Tree Cover, broadleaved, deciduous, closed                       Croplands
#
#                Distribution_of_Cultivation_Intensity  \
# 0  Tall/medium/short grassland with less than 10 ...
# 1  Tall/medium/short grassland with less than 10 ...
# 2  Tall/medium/short grassland with less than 10 ...
# 3  Tall/medium/short grassland with less than 10 ...
# 4    Temperate sbpolar evergreen needleleaved forest
#
#                          Koppen_Geiger  Geological_ages  Soil_types  \
# 0                      Arid/Steppe/Hot         Triassic         4.0
# 1                      Arid/Steppe/Hot         Triassic         4.0
# 2                      Arid/Steppe/Hot         Triassic         4.0
# 3                      Arid/Steppe/Hot         Triassic         4.0
# 4  Cold/Without dry season/Cold summer       Quaternary         4.0
#
#    SoilGrids_TAXNWRB  SoilGrids_TAXOUSDA
# 0  Rendzic Leptosols             Xerolls
# 1  Rendzic Leptosols             Xerolls
# 2  Rendzic Leptosols             Xerolls
# 3  Rendzic Leptosols             Xerolls
# 4    Haplic Luvisols              Udalfs
#
# [5 rows x 252 columns]

# %%
#Data Definition:
print(Data_2.iloc[:, 0:50].dtypes)
# Out:
# CS_number                object
# latitude                float64
# longitude               float64
# Experiment               object
# N_source                 object
# N_concentration         float64
# N_treatment              object
# Leaf_Area               float64
# Total_roots             float64
# PR_length               float64
# Number_of_LR            float64
# Total_LR                float64
# LR_density              float64
# LR_length               float64
# LR_to_total_roots       float64
# LR_to_PR                float64
# X2MSO                   float64
# X3OHP                   float64
# X4OHB                   float64
# X3MSO                   float64
# OH_3_Butenyl            float64
# X4MSO                   float64
# Allyl                   float64
# X5MSO                   float64
# Branches                float64
# X3_Butenyl              float64
# X6MSO                   float64
# X3MT                    float64
# X7MSO                   float64
# X4_Pentenyl             float64
# X4MT                    float64
# X8MSO                   float64
# I3M                     float64
# X4MOI3M                 float64
# Aliphatic               float64
# Indolic                 float64
# C3                      float64
# C4                      float64
# C3_ratio                float64
# Alk                     float64
# GSOH                    float64
# SC                      float64
# LC                      float64
# Total_GSL               float64
# Seeds_classification     object
# id                      float64
# group                    object
# CO_Spring               float64
# CO_Summer               float64
# NO2_Spring              float64
# dtype: object

# %%
#Changing floats to objects:
Data_2 = Data_2.astype({"N_concentration": 'object', "id": 'object'})
print(Data_2.iloc[:, 0:50].dtypes)
# Out:
# CS_number                object
# latitude                float64
# longitude               float64
# Experiment               object
# N_source                 object
# N_concentration          object
# N_treatment              object
# Leaf_Area               float64
# Total_roots             float64
# PR_length               float64
# Number_of_LR            float64
# Total_LR                float64
# LR_density              float64
# LR_length               float64
# LR_to_total_roots       float64
# LR_to_PR                float64
# X2MSO                   float64
# X3OHP                   float64
# X4OHB                   float64
# X3MSO                   float64
# OH_3_Butenyl            float64
# X4MSO                   float64
# Allyl                   float64
# X5MSO                   float64
# Branches                float64
# X3_Butenyl              float64
# X6MSO                   float64
# X3MT                    float64
# X7MSO                   float64
# X4_Pentenyl             float64
# X4MT                    float64
# X8MSO                   float64
# I3M                     float64
# X4MOI3M                 float64
# Aliphatic               float64
# Indolic                 float64
# C3                      float64
# C4                      float64
# C3_ratio                float64
# Alk                     float64
# GSOH                    float64
# SC                      float64
# LC                      float64
# Total_GSL               float64
# Seeds_classification     object
# id                       object
# group                    object
# CO_Spring               float64
# CO_Summer               float64
# NO2_Spring              float64
# dtype: object

# %%
print(Data_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3888 entries, 0 to 3887
# Columns: 252 entries, CS_number to SoilGrids_TAXOUSDA
# dtypes: float64(236), object(16)
# memory usage: 7.5+ MB
# None

# %%
Data_2.iloc[:, 7:45].describe()
# Out:
#          Leaf_Area  Total_roots    PR_length  Number_of_LR     Total_LR  \
# count  3883.000000  3888.000000  3888.000000   3888.000000  3888.000000
# mean      7.847867    69.581121    43.087813      3.794877    26.495104
# std       6.094301    54.001416    18.053545      4.721304    41.403396
# min       0.000000     2.356000     2.356000      0.000000     0.000000
# 25%       4.093565    34.543000    29.933750      0.333333     0.188833
# 50%       6.019308    51.200000    43.073000      2.000000     8.719886
# 75%       9.665373    87.627076    55.704227      5.500000    34.445833
# max      59.278188   379.778000   119.585000     32.000000   300.046500
#
#         LR_density    LR_length  LR_to_total_roots     LR_to_PR         X2MSO  \
# count  3888.000000  2934.000000        3888.000000  3888.000000  3.888000e+03
# mean      0.079033     5.932558           0.206131     0.482134  1.912676e-04
# std       0.085054     3.950685           0.196503     0.611156  8.599780e-03
# min       0.000000     0.000000           0.000000     0.000000  0.000000e+00
# 25%       0.006221     3.100635           0.004185     0.004524  1.630000e-17
# 50%       0.057440     5.279170           0.171639     0.262955  2.400000e-17
# 75%       0.122500     7.891394           0.341926     0.720393  3.192500e-17
# max       1.108214    45.150420           0.810382     4.273764  4.463347e-01
#
#        ...     Aliphatic       Indolic            C3            C4  \
# count  ...  3.888000e+03  3.888000e+03  3.888000e+03  3.888000e+03
# mean   ...  5.198474e-01  7.523269e-02  2.986454e-01  1.480641e-01
# std    ...  1.054713e+00  3.002873e-01  6.765920e-01  7.099700e-01
# min    ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...  3.620000e-13  4.660000e-14  2.747500e-14  0.000000e+00
# 50%    ...  2.195119e-01  2.704375e-02  2.268433e-02  2.840000e-15
# 75%    ...  6.198817e-01  7.548677e-02  3.508087e-01  2.520000e-13
# max    ...  3.193861e+01  1.445273e+01  1.533876e+01  2.947577e+01
#
#           C3_ratio          Alk          GSOH            SC            LC  \
# count  2642.000000  2642.000000  6.900000e+02  3.888000e+03  3.888000e+03
# mean      0.701771     0.739191  3.800391e-01  4.467095e-01  6.828254e-02
# std       0.443693     0.400401  3.459927e-01  9.474815e-01  1.761011e-01
# min       0.000000     0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       0.017450     0.500000  6.945000e-15  1.130000e-13  7.072500e-15
# 50%       1.000000     1.000000  3.591729e-01  1.763468e-01  1.677976e-02
# 75%       1.000000     1.000000  5.992225e-01  5.280321e-01  7.434900e-02
# max       1.000000     1.000000  1.000000e+00  2.947577e+01  4.777901e+00
#
#          Total_GSL
# count  3888.000000
# mean      0.594798
# std       1.195377
# min       0.000000
# 25%       0.045625
# 50%       0.262498
# 75%       0.687701
# max      36.272819
#
# [8 rows x 37 columns]

# %%
Data_2['CS_number'].describe()
# Out:
# count        3888
# unique       1021
# top       CS78367
# freq            4
# Name: CS_number, dtype: object

# %%
Data_2['N_treatment'].describe()
# Out:
# count       3888
# unique         4
# top       KNO3_1
# freq         979
# Name: N_treatment, dtype: object

# %%
print(Data_2['Seeds_classification'].value_counts())
# Out:
# Allyl      1295
# OH-But      705
# 3OHP        424
# 4MSO        191
# 3MSO         87
# Butenyl      36
# 4OHB          8
# Name: Seeds_classification, dtype: int64

# %%
print(Data_2['Experiment'].value_counts())
# Out:
# R    240
# M    238
# N    237
# F    236
# K    236
# O    236
# L    234
# J    233
# Q    233
# H    227
# D    221
# I    221
# G    217
# P    217
# E    210
# C    191
# A    115
# B     97
# S     49
# Name: Experiment, dtype: int64

# %%
#Calculating some statistics for different phenotypes by treatments:
Data_2[["N_treatment", "Leaf_Area", "Total_roots", "PR_length", "Total_GSL"]].groupby("N_treatment").mean()
# Out:
#              Leaf_Area  Total_roots  PR_length  Total_GSL
# N_treatment
# KNO3_0.1      7.322922    73.854633  44.269392   0.407341
# KNO3_1       11.350120    88.772517  48.741566   0.310250
# NH4HCO3_0.1   6.223468    62.087555  41.520168   0.891707
# NH4HCO3_1     6.462975    53.463624  37.773526   0.770718

# %%
#Count missing values in relevant columns:
print(Data_2.iloc[:, 0:10].isnull().sum())
print("Number of samples without GSL data:", Data_2['Total_GSL'].isnull().sum())
# Out:
# CS_number           0
# latitude           11
# longitude          11
# Experiment          0
# N_source            0
# N_concentration     0
# N_treatment         0
# Leaf_Area           5
# Total_roots         0
# PR_length           0
# dtype: int64
# Number of samples without GSL data: 0

# %%
#Finding CS_numbers of missing values in latitude and longitude:
Data_2.loc[Data_2['latitude'].isnull()]
# Out:
#     CS_number  latitude  longitude Experiment N_source N_concentration  \
# 327   CS76470       NaN        NaN          D  NH4HCO3             0.1
# 328   CS76470       NaN        NaN          D  NH4HCO3             1.0
# 329   CS76470       NaN        NaN          D     KNO3             1.0
# 330   CS76470       NaN        NaN          D     KNO3             0.1
# 491   CS76543       NaN        NaN          E  NH4HCO3             1.0
# 492   CS76543       NaN        NaN          E  NH4HCO3             0.1
# 493   CS76543       NaN        NaN          E     KNO3             0.1
# 587   CS76588       NaN        NaN          E     KNO3             1.0
# 588   CS76588       NaN        NaN          E  NH4HCO3             1.0
# 589   CS76588       NaN        NaN          E  NH4HCO3             0.1
# 590   CS76588       NaN        NaN          E     KNO3             0.1
#
#      N_treatment  Leaf_Area  Total_roots  PR_length  ...  \
# 327  NH4HCO3_0.1   6.227962    45.425000  39.480000  ...
# 328    NH4HCO3_1   5.374139    40.755000  40.755000  ...
# 329       KNO3_1   5.971807    37.755000  34.485000  ...
# 330     KNO3_0.1  10.339372   123.836667  44.603333  ...
# 491    NH4HCO3_1   4.806581    47.033333  46.343333  ...
# 492  NH4HCO3_0.1   6.105477   137.590000  66.085000  ...
# 493     KNO3_0.1   8.114817    76.455000  53.400000  ...
# 587       KNO3_1   7.177197    91.420000  59.760000  ...
# 588    NH4HCO3_1   4.933632    36.950000  32.070000  ...
# 589  NH4HCO3_0.1   4.093238    38.060000  31.190000  ...
# 590     KNO3_0.1  10.086868    98.316667  52.440000  ...
#
#      Distance_to_the_coast  Bailey_ecoregions  Land_cover_2000  \
# 327                    NaN                NaN              NaN
# 328                    NaN                NaN              NaN
# 329                    NaN                NaN              NaN
# 330                    NaN                NaN              NaN
# 491                    NaN                NaN              NaN
# 492                    NaN                NaN              NaN
# 493                    NaN                NaN              NaN
# 587                    NaN                NaN              NaN
# 588                    NaN                NaN              NaN
# 589                    NaN                NaN              NaN
# 590                    NaN                NaN              NaN
#
#      UMD_Land_cover_classification  Distribution_of_Cultivation_Intensity  \
# 327                            NaN                                    NaN
# 328                            NaN                                    NaN
# 329                            NaN                                    NaN
# 330                            NaN                                    NaN
# 491                            NaN                                    NaN
# 492                            NaN                                    NaN
# 493                            NaN                                    NaN
# 587                            NaN                                    NaN
# 588                            NaN                                    NaN
# 589                            NaN                                    NaN
# 590                            NaN                                    NaN
#
#      Koppen_Geiger  Geological_ages  Soil_types  SoilGrids_TAXNWRB  \
# 327            NaN              NaN         NaN                NaN
# 328            NaN              NaN         NaN                NaN
# 329            NaN              NaN         NaN                NaN
# 330            NaN              NaN         NaN                NaN
# 491            NaN              NaN         NaN                NaN
# 492            NaN              NaN         NaN                NaN
# 493            NaN              NaN         NaN                NaN
# 587            NaN              NaN         NaN                NaN
# 588            NaN              NaN         NaN                NaN
# 589            NaN              NaN         NaN                NaN
# 590            NaN              NaN         NaN                NaN
#
#      SoilGrids_TAXOUSDA
# 327                 NaN
# 328                 NaN
# 329                 NaN
# 330                 NaN
# 491                 NaN
# 492                 NaN
# 493                 NaN
# 587                 NaN
# 588                 NaN
# 589                 NaN
# 590                 NaN
#
# [11 rows x 252 columns]

# %%
#Filling the missing values:
